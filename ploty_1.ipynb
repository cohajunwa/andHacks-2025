# %%
import pandas as pd
import geopandas as gpd
from dash import Dash, dcc, html
from dash.dependencies import Input, Output
import plotly.express as px
from shapely.geometry import Point

# %%
cvs_loc = "locations.csv"
# Add your Mapbox token here (you can get one from https://account.mapbox.com/access-tokens/)
mapbox_token = "INSERT_TOKEN"

# %%
# Initialize the Dash app
app = Dash(__name__)

# Step 1: Function to load data (including image paths)
def csv_to_geopandas(file_path):
    df = pd.read_csv(file_path,encoding='latin1')
    if 'latitude' not in df.columns or 'longitude' not in df.columns:
        raise ValueError("CSV must contain 'latitude' and 'longitude' columns.")
    
    gdf = gpd.GeoDataFrame(df, 
                           geometry=[Point(xy) for xy in zip(df['longitude'], df['latitude'])], 
                           crs="EPSG:4326")
    
    return gdf

# Load the data
gdf = csv_to_geopandas(cvs_loc)

# Create a Plotly map using Mapbox
def create_map(gdf):
    fig = px.scatter_mapbox(gdf,
                            lat=gdf.geometry.y,
                            lon=gdf.geometry.x,
                            hover_name="name",
                            hover_data=["description", "image"],
                            zoom=6,  # Adjust zoom level for Virginia
                            center={"lat": 37.4316, "lon": -78.6569},  # Center on Virginia
                            height=600)
    
    # Update layout to use the Mapbox token and show street lines
    fig.update_layout(
        mapbox_style="streets",  # Show street lines
        mapbox_accesstoken=mapbox_token,
        margin={"r":0, "t":0, "l":0, "b":0},  # Remove margins for full-screen map
        mapbox_zoom=6,  # Zoom level to focus on Virginia
        mapbox_center={"lat": 37.4316, "lon": -78.6569}
    )
    
    return fig

# Step 3
app.layout = html.Div(style={'position': 'relative'}, children=[
    # Map
    dcc.Graph(id="location-map", style={'position': 'relative', 'z-index': '1'}),
    
    # Image overlay (initially hidden)
    html.Div(id="image-container", style={
        'position': 'absolute',
        'top': '20px',
        'right': '20px',
        'width': '300px',
        'height': '300px',
        'z-index': '2',
        'display': 'none',  # Initially hidden
        'background-color': 'white',
        'padding': '10px',
        'box-shadow': '0px 4px 6px rgba(0, 0, 0, 0.1)',
        'border': '1px solid #ccc'
    }, children=[
        html.Img(id='location-image', style={'max-width': '100%', 'height': 'auto'})
    ]),
    
    # Add interval component for periodic updates
    dcc.Interval(
        id='interval-component',
        interval=0*1000,  # Update every 10 seconds
        n_intervals=0
    )
])

# Step 4: Callback to update the map
@app.callback(
    Output('location-map', 'figure'),
    [Input('interval-component', 'n_intervals')]
)
def update_map(n):
    # Reload the CSV file each time the interval is triggered
    gdf = csv_to_geopandas(cvs_loc)
    return create_map(gdf)

# Callback to update the image and control its visibility
@app.callback(
    [Output('location-image', 'src'),
     Output('image-container', 'style')],
    [Input('location-map', 'clickData')]
)
def update_image(clickData):
    if clickData is None:
        # Hide the image if no point is clicked, but return a valid src (empty string)
        return "", {'display': 'none'}
    
    # Get the image filename from the clicked point
    clicked_point = clickData['points'][0]
    image_name = clicked_point['customdata'][1]  # Assuming 'customdata' has the image filename
    
    # Build the src path for the image
    image_src = f"/assets/images/{image_name}"
    
    # Set the style to make the image visible
    style = {
        'position': 'absolute',
        'top': '20px',
        'right': '20px',
        'width': '300px',
        'height': '400px',
        'z-index': '2',
        'display': 'block',  # Make the image visible
        'background-color': 'white',
        'padding': '10px',
        'box-shadow': '0px 4px 6px rgba(0, 0, 0, 0.1)',
        'border': '1px solid #ccc'
    }
    
    # Return the image path (string) and the style (dict)
    return image_src, style

# Run the app
if __name__ == "__main__":
    app.run_server(debug=True, port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 89, in update_map(n=0)
#      82 @app.callback(
#      83     Output('location-map', 'figure'),
#      84     [Input('interval-component', 'n_intervals')]
#      85 )
#      86 def update_map(n):
#      87     # Reload the CSV file each time the interval is triggered
#      88     gdf = csv_to_geopandas(cvs_loc)
# ---> 89     return create_map(gdf)
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#
# Cell In[93], line 21, in create_map(
#     gdf=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY
# )
#      20 def create_map(gdf):
# ---> 21     fig = px.scatter_mapbox(gdf,
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#         px = <module 'plotly.express' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\express\\__init__.py'>
#      22                             lat=gdf.geometry.y,
#      23                             lon=gdf.geometry.x,
#      24                             hover_name="name",
#      25                             hover_data=["description", "image"],
#      26                             zoom=6,  # Adjust zoom level for Virginia
#      27                             center={"lat": 37.4316, "lon": -78.6569},  # Center on Virginia
#      28                             height=600)
#      30         # Customize the appearance of the hover text using hovertemplate
#      31     fig.update_traces(
#      32         hovertemplate=(
#      33             "<b>%{hovertext}</b><br>"  # Main label (e.g., 'name') in bold
#    (...)
#      37         customdata=gdf[['description']]  # Pass in the data you want to customize
#      38     )
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_chart_types.py:1394, in scatter_mapbox(
#     data_frame=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY  ,
#     lat=0    37.774900
# 1    34.052200
# 2    40.712800
# 3  ... NaN
# 5          NaN
# 6          NaN
# dtype: float64,
#     lon=0   -122.419400
# 1   -118.243700
# 2    -74.006000
# ...aN
# 5           NaN
# 6           NaN
# dtype: float64,
#     color=None,
#     text=None,
#     hover_name='name',
#     hover_data=['description', 'image'],
#     custom_data=None,
#     size=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     opacity=None,
#     size_max=None,
#     zoom=6,
#     center={'lat': 37.4316, 'lon': -78.6569},
#     mapbox_style=None,
#     title=None,
#     template=None,
#     width=None,
#     height=600
# )
#    1361 def scatter_mapbox(
#    1362     data_frame=None,
#    1363     lat=None,
#    (...)
#    1388     height=None,
#    1389 ) -> go.Figure:
#    1390     """
#    1391     In a Mapbox scatter plot, each row of `data_frame` is represented by a
#    1392     symbol mark on a Mapbox map.
#    1393     """
# -> 1394     return make_figure(args=locals(), constructor=go.Scattermapbox)
#         go = <module 'plotly.graph_objs' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\graph_objs\\__init__.py'>
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:2117, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2114 layout_patch = layout_patch or {}
#    2115 apply_default_cascade(args)
# -> 2117 args = build_dataframe(args, constructor)
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         constructor = <class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
#    2118 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2119     args = process_dataframe_hierarchy(args)
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1513, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
# )
#    1510     args["color"] = None
#    1511 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1513 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1514     args, wide_mode, var_name, value_name
#    1515 )
#    1517 # now that `df_output` exists and `args` contains only references, we complete
#    1518 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1519 # df_output
#    1521 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1234, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1232         if argument == "index":
#    1233             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1234         raise ValueError(err_msg)
#         err_msg = "Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name"
#    1235 elif length and len(df_input[argument]) != length:
#    1236     raise ValueError(
#    1237         "All arguments should have the same length. "
#    1238         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1245         )
#    1246     )
#
# ValueError: Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 89, in update_map(n=0)
#      82 @app.callback(
#      83     Output('location-map', 'figure'),
#      84     [Input('interval-component', 'n_intervals')]
#      85 )
#      86 def update_map(n):
#      87     # Reload the CSV file each time the interval is triggered
#      88     gdf = csv_to_geopandas(cvs_loc)
# ---> 89     return create_map(gdf)
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#
# Cell In[93], line 21, in create_map(
#     gdf=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY
# )
#      20 def create_map(gdf):
# ---> 21     fig = px.scatter_mapbox(gdf,
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#         px = <module 'plotly.express' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\express\\__init__.py'>
#      22                             lat=gdf.geometry.y,
#      23                             lon=gdf.geometry.x,
#      24                             hover_name="name",
#      25                             hover_data=["description", "image"],
#      26                             zoom=6,  # Adjust zoom level for Virginia
#      27                             center={"lat": 37.4316, "lon": -78.6569},  # Center on Virginia
#      28                             height=600)
#      30         # Customize the appearance of the hover text using hovertemplate
#      31     fig.update_traces(
#      32         hovertemplate=(
#      33             "<b>%{hovertext}</b><br>"  # Main label (e.g., 'name') in bold
#    (...)
#      37         customdata=gdf[['description']]  # Pass in the data you want to customize
#      38     )
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_chart_types.py:1394, in scatter_mapbox(
#     data_frame=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY  ,
#     lat=0    37.774900
# 1    34.052200
# 2    40.712800
# 3  ... NaN
# 5          NaN
# 6          NaN
# dtype: float64,
#     lon=0   -122.419400
# 1   -118.243700
# 2    -74.006000
# ...aN
# 5           NaN
# 6           NaN
# dtype: float64,
#     color=None,
#     text=None,
#     hover_name='name',
#     hover_data=['description', 'image'],
#     custom_data=None,
#     size=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     opacity=None,
#     size_max=None,
#     zoom=6,
#     center={'lat': 37.4316, 'lon': -78.6569},
#     mapbox_style=None,
#     title=None,
#     template=None,
#     width=None,
#     height=600
# )
#    1361 def scatter_mapbox(
#    1362     data_frame=None,
#    1363     lat=None,
#    (...)
#    1388     height=None,
#    1389 ) -> go.Figure:
#    1390     """
#    1391     In a Mapbox scatter plot, each row of `data_frame` is represented by a
#    1392     symbol mark on a Mapbox map.
#    1393     """
# -> 1394     return make_figure(args=locals(), constructor=go.Scattermapbox)
#         go = <module 'plotly.graph_objs' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\graph_objs\\__init__.py'>
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:2117, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2114 layout_patch = layout_patch or {}
#    2115 apply_default_cascade(args)
# -> 2117 args = build_dataframe(args, constructor)
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         constructor = <class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
#    2118 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2119     args = process_dataframe_hierarchy(args)
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1513, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
# )
#    1510     args["color"] = None
#    1511 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1513 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1514     args, wide_mode, var_name, value_name
#    1515 )
#    1517 # now that `df_output` exists and `args` contains only references, we complete
#    1518 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1519 # df_output
#    1521 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1234, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1232         if argument == "index":
#    1233             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1234         raise ValueError(err_msg)
#         err_msg = "Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name"
#    1235 elif length and len(df_input[argument]) != length:
#    1236     raise ValueError(
#    1237         "All arguments should have the same length. "
#    1238         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1245         )
#    1246     )
#
# ValueError: Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 89, in update_map(n=0)
#      82 @app.callback(
#      83     Output('location-map', 'figure'),
#      84     [Input('interval-component', 'n_intervals')]
#      85 )
#      86 def update_map(n):
#      87     # Reload the CSV file each time the interval is triggered
#      88     gdf = csv_to_geopandas(cvs_loc)
# ---> 89     return create_map(gdf)
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#
# Cell In[93], line 21, in create_map(
#     gdf=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY
# )
#      20 def create_map(gdf):
# ---> 21     fig = px.scatter_mapbox(gdf,
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#         px = <module 'plotly.express' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\express\\__init__.py'>
#      22                             lat=gdf.geometry.y,
#      23                             lon=gdf.geometry.x,
#      24                             hover_name="name",
#      25                             hover_data=["description", "image"],
#      26                             zoom=6,  # Adjust zoom level for Virginia
#      27                             center={"lat": 37.4316, "lon": -78.6569},  # Center on Virginia
#      28                             height=600)
#      30         # Customize the appearance of the hover text using hovertemplate
#      31     fig.update_traces(
#      32         hovertemplate=(
#      33             "<b>%{hovertext}</b><br>"  # Main label (e.g., 'name') in bold
#    (...)
#      37         customdata=gdf[['description']]  # Pass in the data you want to customize
#      38     )
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_chart_types.py:1394, in scatter_mapbox(
#     data_frame=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY  ,
#     lat=0    37.774900
# 1    34.052200
# 2    40.712800
# 3  ... NaN
# 5          NaN
# 6          NaN
# dtype: float64,
#     lon=0   -122.419400
# 1   -118.243700
# 2    -74.006000
# ...aN
# 5           NaN
# 6           NaN
# dtype: float64,
#     color=None,
#     text=None,
#     hover_name='name',
#     hover_data=['description', 'image'],
#     custom_data=None,
#     size=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     opacity=None,
#     size_max=None,
#     zoom=6,
#     center={'lat': 37.4316, 'lon': -78.6569},
#     mapbox_style=None,
#     title=None,
#     template=None,
#     width=None,
#     height=600
# )
#    1361 def scatter_mapbox(
#    1362     data_frame=None,
#    1363     lat=None,
#    (...)
#    1388     height=None,
#    1389 ) -> go.Figure:
#    1390     """
#    1391     In a Mapbox scatter plot, each row of `data_frame` is represented by a
#    1392     symbol mark on a Mapbox map.
#    1393     """
# -> 1394     return make_figure(args=locals(), constructor=go.Scattermapbox)
#         go = <module 'plotly.graph_objs' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\graph_objs\\__init__.py'>
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:2117, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2114 layout_patch = layout_patch or {}
#    2115 apply_default_cascade(args)
# -> 2117 args = build_dataframe(args, constructor)
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         constructor = <class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
#    2118 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2119     args = process_dataframe_hierarchy(args)
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1513, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
# )
#    1510     args["color"] = None
#    1511 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1513 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1514     args, wide_mode, var_name, value_name
#    1515 )
#    1517 # now that `df_output` exists and `args` contains only references, we complete
#    1518 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1519 # df_output
#    1521 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1234, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1232         if argument == "index":
#    1233             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1234         raise ValueError(err_msg)
#         err_msg = "Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name"
#    1235 elif length and len(df_input[argument]) != length:
#    1236     raise ValueError(
#    1237         "All arguments should have the same length. "
#    1238         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1245         )
#    1246     )
#
# ValueError: Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name
#
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 89, in update_map(n=0)
#      82 @app.callback(
#      83     Output('location-map', 'figure'),
#      84     [Input('interval-component', 'n_intervals')]
#      85 )
#      86 def update_map(n):
#      87     # Reload the CSV file each time the interval is triggered
#      88     gdf = csv_to_geopandas(cvs_loc)
# ---> 89     return create_map(gdf)
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#
# Cell In[93], line 21, in create_map(
#     gdf=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY
# )
#      20 def create_map(gdf):
# ---> 21     fig = px.scatter_mapbox(gdf,
#         gdf =               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY
#         px = <module 'plotly.express' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\express\\__init__.py'>
#      22                             lat=gdf.geometry.y,
#      23                             lon=gdf.geometry.x,
#      24                             hover_name="name",
#      25                             hover_data=["description", "image"],
#      26                             zoom=6,  # Adjust zoom level for Virginia
#      27                             center={"lat": 37.4316, "lon": -78.6569},  # Center on Virginia
#      28                             height=600)
#      30         # Customize the appearance of the hover text using hovertemplate
#      31     fig.update_traces(
#      32         hovertemplate=(
#      33             "<b>%{hovertext}</b><br>"  # Main label (e.g., 'name') in bold
#    (...)
#      37         customdata=gdf[['description']]  # Pass in the data you want to customize
#      38     )
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_chart_types.py:1394, in scatter_mapbox(
#     data_frame=              Name   latitude    longitude      ...
# 6  Artbuilding.jpg                 POINT EMPTY  ,
#     lat=0    37.774900
# 1    34.052200
# 2    40.712800
# 3  ... NaN
# 5          NaN
# 6          NaN
# dtype: float64,
#     lon=0   -122.419400
# 1   -118.243700
# 2    -74.006000
# ...aN
# 5           NaN
# 6           NaN
# dtype: float64,
#     color=None,
#     text=None,
#     hover_name='name',
#     hover_data=['description', 'image'],
#     custom_data=None,
#     size=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     color_continuous_scale=None,
#     range_color=None,
#     color_continuous_midpoint=None,
#     opacity=None,
#     size_max=None,
#     zoom=6,
#     center={'lat': 37.4316, 'lon': -78.6569},
#     mapbox_style=None,
#     title=None,
#     template=None,
#     width=None,
#     height=600
# )
#    1361 def scatter_mapbox(
#    1362     data_frame=None,
#    1363     lat=None,
#    (...)
#    1388     height=None,
#    1389 ) -> go.Figure:
#    1390     """
#    1391     In a Mapbox scatter plot, each row of `data_frame` is represented by a
#    1392     symbol mark on a Mapbox map.
#    1393     """
# -> 1394     return make_figure(args=locals(), constructor=go.Scattermapbox)
#         go = <module 'plotly.graph_objs' from 'c:\\Users\\kalea\\anaconda3\\lib\\site-packages\\plotly\\graph_objs\\__init__.py'>
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:2117, in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>,
#     trace_patch={},
#     layout_patch={}
# )
#    2114 layout_patch = layout_patch or {}
#    2115 apply_default_cascade(args)
# -> 2117 args = build_dataframe(args, constructor)
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         constructor = <class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
#    2118 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2119     args = process_dataframe_hierarchy(args)
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1513, in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     constructor=<class 'plotly.graph_objs._scattermapbox.Scattermapbox'>
# )
#    1510     args["color"] = None
#    1511 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1513 df_output, wide_id_vars = process_args_into_dataframe(
#         args = {'data_frame':               Name   latitude    longitude                  ADA_Violation  \
# 0   Kalea Anderson  37.774900    -122.4194                   No elevators
# 1      Comfort Wen  34.052200    -118.2437         No handicapped parking
# 2  Philip Ohajunwa  40.712800      -74.006  No ADA bathroom Accessibility
# 3  Kayla Matejivic  37.271133   -76.716614           No wheelchair access
# 4        Bob Kelly        NaN          NaN                        No ramp
# 5        Bob Kelly        NaN          NaN                 Not Steve Jobs
# 6        Bob Kelly        NaN          NaN             No dust regulation
#
#              image                    geometry
# 0           SF.jpg   POINT (-122.4194 37.7749)
# 1           LA.jpg   POINT (-118.2437 34.0522)
# 2           NY.jpg     POINT (-74.006 40.7128)
# 3     backswem.jpg  POINT (-76.71661 37.27113)
# 4     baseswem.jpg                 POINT EMPTY
# 5     PhilJobs.jpg                 POINT EMPTY
# 6  Artbuilding.jpg                 POINT EMPTY  , 'lat': 0    37.774900
# 1    34.052200
# 2    40.712800
# 3    37.271133
# 4          NaN
# 5          NaN
# 6          NaN
# dtype: float64, 'lon': 0   -122.419400
# 1   -118.243700
# 2    -74.006000
# 3    -76.716614
# 4           NaN
# 5           NaN
# 6           NaN
# dtype: float64, 'color': None, 'text': None, 'hover_name': 'name', 'hover_data': ['description', 'image'], 'custom_data': None, 'size': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'color_continuous_scale': None, 'range_color': None, 'color_continuous_midpoint': None, 'opacity': None, 'size_max': None, 'zoom': 6, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'mapbox_style': None, 'title': None, 'template': None, 'width': None, 'height': 600}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1514     args, wide_mode, var_name, value_name
#    1515 )
#    1517 # now that `df_output` exists and `args` contains only references, we complete
#    1518 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1519 # df_output
#    1521 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File c:\Users\kalea\anaconda3\lib\site-packages\plotly\express\_core.py:1234, in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'center': {'lat': 37.4316, 'lon': -78.6569}, 'color': None, 'color_continuous_midpoint': None, 'color_continuous_scale': None, 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1232         if argument == "index":
#    1233             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1234         raise ValueError(err_msg)
#         err_msg = "Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name"
#    1235 elif length and len(df_input[argument]) != length:
#    1236     raise ValueError(
#    1237         "All arguments should have the same length. "
#    1238         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1245         )
#    1246     )
#
# ValueError: Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'latitude', 'longitude', 'ADA_Violation', 'image', 'geometry'] but received: name
